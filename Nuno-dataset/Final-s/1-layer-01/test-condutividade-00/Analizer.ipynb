# %%
import pandas as pd
import numpy as np

def read_excel(file_name):
    df = pd.read_excel(file_name)
    return df

def read_txt(file_name):
    file = open(file_name)
    lines = file.readlines()
    return(lines[0])

# %%
import os
import glob

def get_files(subfolder, extension):
    dir = f"{os.getcwd()}/content/{subfolder}/"
    tables = glob.glob(f"{dir}*.{extension}")
    return tables

# %%
class Analizer:
    def __init__(self, boundary):
        self.results = get_files(subfolder="results", extension="xlsx")
        self.results_df = pd.DataFrame()
        self.boundary = boundary
    
    def has_minimum_requirements(self, df, sort_by="r2"):
        sorted_df = df.sort_values(by=sort_by, ascending=False)
        top_r2 = sorted_df.head(1)[sort_by].values[0]
        if top_r2 < self.boundary:
            return False
        return True
    
    def concatenate_df(self, df, architecture):
        if self.has_minimum_requirements(df):
            df['Architecture'] = architecture
            df = df.rename(columns={'Unnamed: 0': 'model'})
            self.results_df = pd.concat([self.results_df, df], ignore_index=True) 

    def create_results_df(self):
        for file in self.results:
            df = read_excel(file)
            architecture = read_txt(file.replace(".xlsx", ".txt"))
            self.concatenate_df(df, architecture)
        self.results_df = self.results_df.sort_values(by="r2", ascending=False, ignore_index=True)

    def discard_below_average(self, sort_by):
        column_mean = self.results_df[sort_by].mean()      
        self.results_df = self.results_df[self.results_df[sort_by] >= column_mean]
    
    def discard_high_standard_deviation(self):
        r2_val, r2_test = self.results_df['r2_val'], self.results_df['r2_test']
        std_devs = np.abs(r2_val - r2_test)
        mean_std_dev = std_devs.mean()
        self.results_df = self.results_df[std_devs < mean_std_dev]

    def clean_folder(self, subfolder, extension, remove_last=True):
        files = get_files(subfolder, extension)
        models = self.results_df["model"]
        if (remove_last):
            models = models.apply(lambda x: '_'.join(x.rsplit('_', 1)[:-1]))
        for file in files:
            file_name = os.path.basename(file).split('.')[0]
            file_parts = file_name.split('_')            
            dataset_model = f"model_{file_parts[1]}_{file_parts[2]}" 
            if (remove_last == False):
                dataset_model = (f"{dataset_model}_{file_parts[3]}")
            if dataset_model not in models.values:
                os.remove(file)   
        
    def Analize(self):
        self.create_results_df()
        self.discard_below_average(sort_by="r2")
        self.discard_below_average(sort_by="r2_vt")
        # self.discard_high_standard_deviation()
        self.results_df.to_excel(f"better_results.xlsx", index=True)
        display(self.results_df)

# %%
analize = Analizer(0.9)
analize.Analize()
analize.clean_folder(subfolder="dataset", extension="pkl")
analize.clean_folder(subfolder="results", extension="xlsx")
analize.clean_folder(subfolder="results", extension="txt")
analize.clean_folder(subfolder="models", extension="keras", remove_last=False)
# Out:
#             model        r2   r2_test    r2_val     r2_vt       mse  mse_test  \
# 0    model_17_9_8  0.997584  0.993598  0.996861  0.995118  0.000452  0.001497
# 1    model_17_9_7  0.997575  0.994248  0.996867  0.995471  0.000454  0.001345
# 2    model_17_9_9  0.997572  0.992979  0.996850  0.994778  0.000454  0.001641
# 40  model_17_8_13  0.994379  0.971329  0.991654  0.984069  0.001051  0.003583
# 45  model_17_8_12  0.994284  0.972152  0.991983  0.984582  0.001069  0.003481
# 46  model_17_8_11  0.994142  0.973035  0.992333  0.985132  0.001096  0.003370
# 49  model_17_8_10  0.993941  0.973980  0.992705  0.985717  0.001134  0.003252
# 50    model_5_8_2  0.993925  0.942742  0.994188  0.986726  0.001137  0.001660
# 51    model_5_8_3  0.993837  0.927577  0.991169  0.981964  0.001153  0.002100
# 53    model_5_8_1  0.993723  0.956417  0.996633  0.990786  0.001174  0.001264
# 54   model_17_8_9  0.993662  0.974986  0.993096  0.986338  0.001186  0.003126
# 59   model_17_8_8  0.993287  0.976049  0.993504  0.986990  0.001256  0.002993
# 61    model_5_8_0  0.993138  0.967654  0.998273  0.993812  0.001284  0.000938
# 66   model_17_8_7  0.992787  0.977164  0.993924  0.987669  0.001349  0.002854
# 75   model_17_8_6  0.992131  0.978323  0.994352  0.988370  0.001472  0.002709
# 77   model_15_9_6  0.991364  0.959004  0.987515  0.982519  0.001616  0.003718
# 78   model_15_9_5  0.991299  0.964987  0.989138  0.984962  0.001628  0.003176
# 80   model_17_8_5  0.991277  0.979515  0.994777  0.989082  0.001632  0.002560
# 83   model_15_9_4  0.991043  0.970964  0.990749  0.987396  0.001676  0.002634
# 97   model_15_9_3  0.990532  0.976752  0.992297  0.989747  0.001771  0.002109
#
#      mse_val    mse_vt                                       Architecture
# 0   0.000693  0.001119  Hidden Size=[45], regularizer=0.01, learning_r...
# 1   0.000692  0.001038  Hidden Size=[45], regularizer=0.01, learning_r...
# 2   0.000696  0.001196  Hidden Size=[45], regularizer=0.01, learning_r...
# 3   0.000699  0.001270  Hidden Size=[45], regularizer=0.01, learning_r...
# 4   0.000692  0.000954  Hidden Size=[45], regularizer=0.01, learning_r...
# 5   0.000703  0.001340  Hidden Size=[45], regularizer=0.01, learning_r...
# 6   0.000707  0.001405  Hidden Size=[45], regularizer=0.01, learning_r...
# 7   0.000695  0.000869  Hidden Size=[45], regularizer=0.01, learning_r...
# 8   0.000712  0.001466  Hidden Size=[45], regularizer=0.01, learning_r...
# 9   0.000716  0.001523  Hidden Size=[45], regularizer=0.01, learning_r...
# 10  0.000701  0.000785  Hidden Size=[45], regularizer=0.01, learning_r...
# 11  0.000721  0.001575  Hidden Size=[45], regularizer=0.01, learning_r...
# 12  0.000725  0.001624  Hidden Size=[45], regularizer=0.01, learning_r...
# 13  0.000730  0.001668  Hidden Size=[45], regularizer=0.01, learning_r...
# 14  0.000734  0.001709  Hidden Size=[45], regularizer=0.01, learning_r...
# 15  0.000711  0.000703  Hidden Size=[45], regularizer=0.01, learning_r...
# 16  0.000738  0.001746  Hidden Size=[45], regularizer=0.01, learning_r...
# 17  0.000741  0.001780  Hidden Size=[45], regularizer=0.01, learning_r...
# 18  0.000745  0.001811  Hidden Size=[45], regularizer=0.01, learning_r...
# 19  0.000748  0.001840  Hidden Size=[45], regularizer=0.01, learning_r...
# 20  0.000751  0.001865  Hidden Size=[45], regularizer=0.01, learning_r...
# 21  0.000753  0.001889  Hidden Size=[45], regularizer=0.01, learning_r...
# 22  0.000726  0.000627  Hidden Size=[45], regularizer=0.01, learning_r...
# 23  0.000748  0.000561  Hidden Size=[45], regularizer=0.01, learning_r...
# 24  0.000779  0.000509  Hidden Size=[45], regularizer=0.01, learning_r...
# 25  0.001577  0.002265  Hidden Size=[40], regularizer=0.1, learning_ra...
# 26  0.001527  0.002038  Hidden Size=[40], regularizer=0.1, learning_ra...
# 27  0.001624  0.002486  Hidden Size=[40], regularizer=0.1, learning_ra...
# 28  0.001475  0.001809  Hidden Size=[40], regularizer=0.1, learning_ra...
# 29  0.001669  0.002698  Hidden Size=[40], regularizer=0.1, learning_ra...
# 30  0.002173  0.003059  Hidden Size=[45], regularizer=0.01, learning_r...
# 31  0.002230  0.003126  Hidden Size=[45], regularizer=0.01, learning_r...
# 32  0.002110  0.002987  Hidden Size=[45], regularizer=0.01, learning_r...
# 33  0.002283  0.003187  Hidden Size=[45], regularizer=0.01, learning_r...
# 34  0.002331  0.003243  Hidden Size=[45], regularizer=0.01, learning_r...
# 35  0.002043  0.002909  Hidden Size=[45], regularizer=0.01, learning_r...
# 38  0.001422  0.001583  Hidden Size=[40], regularizer=0.1, learning_ra...
# 40  0.001971  0.002824  Hidden Size=[45], regularizer=0.01, learning_r...
# 45  0.001893  0.002734  Hidden Size=[45], regularizer=0.01, learning_r...
# 46  0.001810  0.002636  Hidden Size=[45], regularizer=0.01, learning_r...
# 49  0.001723  0.002532  Hidden Size=[45], regularizer=0.01, learning_r...
# 50  0.001091  0.001393  Hidden Size=[15], regularizer=0.01, learning_r...
# 51  0.001658  0.001892  Hidden Size=[15], regularizer=0.01, learning_r...
# 53  0.000632  0.000967  Hidden Size=[15], regularizer=0.01, learning_r...
# 54  0.001630  0.002422  Hidden Size=[45], regularizer=0.01, learning_r...
# 59  0.001534  0.002307  Hidden Size=[45], regularizer=0.01, learning_r...
# 61  0.000324  0.000649  Hidden Size=[15], regularizer=0.01, learning_r...
# 66  0.001435  0.002186  Hidden Size=[45], regularizer=0.01, learning_r...
# 75  0.001334  0.002062  Hidden Size=[45], regularizer=0.01, learning_r...
# 77  0.002677  0.003228  Hidden Size=[40], regularizer=0.01, learning_r...
# 78  0.002329  0.002777  Hidden Size=[40], regularizer=0.01, learning_r...
# 80  0.001233  0.001936  Hidden Size=[45], regularizer=0.01, learning_r...
# 83  0.001983  0.002328  Hidden Size=[40], regularizer=0.01, learning_r...
# 97  0.001651  0.001893  Hidden Size=[40], regularizer=0.01, learning_r...
